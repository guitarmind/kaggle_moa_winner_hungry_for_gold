# %%
"""
[V6]
Blend 4 Models:
* kibuna-nn-hs-1024-last-train (aka. 2stage-NN, LB: 0.01822)
* simpleNN-oldcv (LB: 0.01836)
* deepinsight-efficientnet-v7-b3-infer (LB: 0.01850)
* deepinsight_resnest_lightning_v2_infer (LB: 0.01854)

Removed for now due to low weights:
* 503-203-tabnet-with-nonscored-features (LB: 0.01836)
* fork-of-2heads-looper-super-puper-markpeng-infer (LB: 0.1836)

"""

kernel_mode = False

import os
import numpy as np
import pandas as pd
import time
import random
import math
import datetime
import pickle
from pickle import dump, load
import glob

from numba import njit
from scipy.optimize import minimize, fsolve

import optuna

import warnings
warnings.filterwarnings('ignore')

import gc
gc.enable()

rand_seed = 1120

search_mode = True
run_submit_script = False

# method = "CV"
method = "scipy_per_target"
# method = "scipy"
# method = "optuna"
study_name = "blend_search_optuna_v6_per_target"
# n_trials = 500
n_trials = 3000
# n_trials = 5000

# %%
# !mkdir -p /root/.cache/torch/hub/checkpoints/
# !cp ../input/gen-efficientnet-pretrained/tf_efficientnet_*.pth /root/.cache/torch/hub/checkpoints/
# !cp ../input/deepinsight-resnest-v1-resnest50/*.pth /root/.cache/torch/hub/checkpoints/
# !cp ../input/deepinsight-resnest-v2-resnest50-output/*.pth /root/.cache/torch/hub/checkpoints/
# !ls -la /root/.cache/torch/hub/checkpoints/

# %%
# !cp ../input/kaggle-moa-team/scripts/* .
# !ls -la

# %%
dataset_folder = "../input/lish-moa" if kernel_mode else "/workspace/Kaggle/MoA/"

# Add your model inference script here
# Tuple Format: (script, oof_filename, output_filename, weight)
model_list = [
    ("2stageNN_with_ns_oldcv.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/2stageNN_with_ns_oldcv.py",
     "../../Github/kaggle_moa_team/oof/oof_2stageNN_ns_oldcv.npy",
     "submission_2stageNN_with_ns_oldcv_0.01822.csv",
     0.323528084383917),
    
    ("script_simpleNN_oldcv.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/script_simpleNN_oldcv.py",
     "../../Github/kaggle_moa_team/oof/oof_script_simpleNN_oldcv.npy",
     "submission_script_simpleNN_oldcv_0.01836.csv",
     0.08786476491118465),
    
    #     ("fork-of-2heads-looper-super-puper-markpeng-infer.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/fork-of-2heads-looper-super-puper-markpeng-infer.py",
    #      "../../Github/kaggle_moa_team/oof/oof_fork-of-2heads-looper-super-puper-markpeng.npy",
    #      "submission_2heads-looper-super-puper_0.01836.csv",
    #      0.018966959973949222),
    
    ("deepinsight_efficientnet_lightning_v7_b3_infer.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/deepinsight_efficientnet_lightning_v7_b3_infer.py",
     "../../Github/kaggle_moa_team/oof/oof_deepinsight_efficientnet_lightning_v7_b3_0.01850.npy",
     "submission_effnet_v7_b3_0.01850.csv",
     0.21849845883367852),
    
    #     ("script_tabnet_ns_oldcv.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/script_tabnet_ns_oldcv.py",
    #      "../../Github/kaggle_moa_team/oof/oof_tabnet_ns_oldcv.npy",
    #      "submission_tabnet_ns_oldcv_0.01836.csv",
    #      0.0013224625996093413),
    
    ("deepinsight_resnest_lightning_v2_infer.py" if kernel_mode else "../../Github/kaggle_moa_team/scripts/deepinsight_resnest_lightning_v2_infer.py",
     "../../Github/kaggle_moa_team/oof/oof_deepinsight_ResNeSt_v2_resnest50_0.01854.npy",
     "submission_resnest_v2_0.01854.csv",
     0.3704230222796271),
]

model_path = "." if kernel_mode else dataset_folder

# %%
train_features = pd.read_csv(f"{dataset_folder}/train_features.csv",
                             engine='c')
train_labels = pd.read_csv(f'{dataset_folder}/train_targets_scored.csv',
                           engine='c')
train_classes = [c for c in train_labels.columns if c != "sig_id"]

non_control_group_rows = train_features["cp_type"] == "trt_cp"
non_control_group_train_labels = train_labels.loc[
    non_control_group_rows, :].copy().reset_index(drop=True)

submission = pd.read_csv(f'{dataset_folder}/sample_submission.csv')
submission.iloc[:, 1:] = 0

# %%
def mean_logloss(y_pred, y_true):
    logloss = (1 - y_true) * np.log(1 - y_pred +
                                    1e-15) + y_true * np.log(y_pred + 1e-15)
    return np.nanmean(-logloss)


def save_pickle(obj, folder, name):
    dump(obj, open(f"{folder}/{name}.pkl", 'wb'), pickle.HIGHEST_PROTOCOL)


def load_pickle(path):
    return load(open(path, 'rb'))

# %%
# Reference: https://www.kaggle.com/gogo827jz/optimise-blending-weights-with-bonus-0/notebook
# CPMP's logloss from https://www.kaggle.com/c/lish-moa/discussion/183010
def log_loss_numpy(y_pred, y_true):
    y_true_ravel = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)
    loss = np.where(y_true_ravel == 1, -np.log(y_pred),
                    -np.log(1 - y_pred))
    return loss.mean()

def func_numpy_metric(weights):
    oof_blend = np.tensordot(weights, all_oof, axes=((0), (0)))
    return log_loss_numpy(oof_blend, y_true)

@njit
def grad_func_jit(weights):
    oof_clip = np.minimum(1 - 1e-15, np.maximum(all_oof, 1e-15))
    gradients = np.zeros(all_oof.shape[0])
    for i in range(all_oof.shape[0]):
        a, b, c = y_true, oof_clip[i], np.zeros(
            (all_oof.shape[1], all_oof.shape[2]))
        for j in range(oof.shape[0]):
            if j != i:
                c += weights[j] * oof_clip[j]
        gradients[i] = -np.mean(
            (-a * b + (b**2) * weights[i] + b * c) /
            ((b**2) *
             (weights[i]**2) + 2 * b * c * weights[i] - b * weights[i] +
             (c**2) - c))
    return gradients

# %% [markdown]
# ## Bayesian Optimization and Sequential Least Squares Programming (SLSQP)
# https://optuna.readthedocs.io/en/stable/reference/generated/optuna.samplers.TPESampler.html#optuna.samplers.TPESampler
#
# https://docs.scipy.org/doc/scipy/reference/optimize.minimize-slsqp.html

# %%
def run_inference_scripts(submission, weights=None, target_weights=None):
    for i, (script, oof_filename, output_filename, weight) in enumerate(model_list):
        print(f"Generating submission file from {script} ......")
        infer_start = time.time()
        # !python {model_path}/{script}
        infer_elapsed = time.time() - infer_start
        print(f"Time spent on inference: {infer_elapsed/60:.2f} minutes.")

        model_submit = pd.read_csv(output_filename, engine='c')
        print(model_submit.head(5))
        print(model_submit.shape)

        if weights is None:
            print(f"Blending {script} with weight: {weight} ......")
            submission.iloc[:, 1:] += weight * model_submit.iloc[:, 1:]
        elif target_weights is not None:
            for j, target in enumerate(train_classes):
                print(f"Blending {script} for {target} with weight: {optimized_target_weights[j][i]} ......")
                submission.iloc[:, j] += optimized_target_weights[j][i] * model_submit.iloc[:, j]
        else:
            print(f"Blending {script} with weight: {weights[i]} ......")
            submission.iloc[:, 1:] += weights[i] * model_submit.iloc[:, 1:]

    return submission

# %%
# blend_targets_oof = np.zeros(
#     (non_control_group_train_labels.shape[0], 206))
# for i, (script, oof_filename, output_filename,
#         weight) in enumerate(model_list):
#     print(f"Loading OOF from {oof_filename} ......")
#     oof = np.load(f"{dataset_folder}/{oof_filename}")

#     if oof.shape[0] == 23814:
#         oof = oof[non_control_group_rows, :]

#     for j in range(206):
#         blend_targets_oof[:,
#                           j] += oof[:, j] * optimized_target_weights[j][i]

#     oof_loss = mean_logloss(oof, y_true)
#     print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")

# %%
total_start = time.time()

if not search_mode:
    submission = run_inference_scripts(submission)
elif search_mode and method == "CV":
    y_true = non_control_group_train_labels[train_classes].values

    all_oof = np.zeros(
        (len(model_list), non_control_group_train_labels.shape[0], 206))
    blend_oof = np.zeros((non_control_group_train_labels.shape[0], 206))
    print(all_oof.shape)
    for i, (script, oof_filename, output_filename,
            weight) in enumerate(model_list):
        print(f"Loading OOF from {oof_filename} ......")
        oof = np.load(f"{dataset_folder}/{oof_filename}")

        if oof.shape[0] == 23814:
            oof = oof[non_control_group_rows, :]

        all_oof[i, :, :] = oof
        blend_oof += oof * weight

        oof_loss = mean_logloss(oof, y_true)
        print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")

    blend_oof_loss = mean_logloss(blend_oof, y_true)
    print(f"Blend OOF Validation Loss: {blend_oof_loss:.6f}\n")

elif search_mode and method == "optuna":
    print("[Optuna]")
    ## Search Best Blend Weights by Optuna ##
    model_oofs = []

    for i, (script, oof_filename, output_filename,
            weight) in enumerate(model_list):
        print(f"Loading OOF from {oof_filename} ......")
        oof = np.load(f"{dataset_folder}/{oof_filename}")

        if oof.shape[0] == 23814:
            oof = oof[non_control_group_rows, :]

        oof_loss = mean_logloss(
            oof, non_control_group_train_labels[train_classes].values)
        print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")
        model_oofs.append(oof)

    def objective(trial):
        weights = []
        for i in range(len(model_list)):
            weights.append(trial.suggest_float(f"w{i}", 0, 1.0))

        blend = np.zeros(model_oofs[0].shape)
        for i in range(len(model_list)):
            blend += weights[i] * model_oofs[i]
        blend = np.clip(blend, 0, 1.0)

        loss = mean_logloss(
            blend, non_control_group_train_labels[train_classes].values)
        return loss

    pruner = optuna.pruners.MedianPruner(
        n_startup_trials=5,
        n_warmup_steps=0,
        interval_steps=1,
    )
    sampler = optuna.samplers.TPESampler(seed=rand_seed)
    study = optuna.create_study(direction="minimize",
                                pruner=pruner,
                                sampler=sampler,
                                study_name=study_name,
                                storage=f'sqlite:///{study_name}.db',
                                load_if_exists=True)

    study.optimize(objective,
                   n_trials=n_trials,
                   timeout=None,
                   gc_after_trial=True,
                   n_jobs=-1)

    trial = study.best_trial

    if run_submit_script:
        optimal_weights = []
        for i, (script, oof_filename, output_filename,
                _) in enumerate(model_list):
            optimal_weights.append(trial.params[f"w{i}"])
        submission = run_inference_scripts(submission, weights=optimal_weights)

    print("\n[Optuna]")
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Best trial:")
    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

elif search_mode and method == "scipy":
    print("[Scipy SLSQP]")
    # Optimise Blending Weights with Bonus
    # https://www.kaggle.com/gogo827jz/optimise-blending-weights-with-bonus-0/notebook
    model_oofs = []
    y_true = non_control_group_train_labels[train_classes].values

    all_oof = np.zeros(
        (len(model_list), non_control_group_train_labels.shape[0], 206))
    print(all_oof.shape)
    for i, (script, oof_filename, output_filename,
            weight) in enumerate(model_list):
        print(f"Loading OOF from {oof_filename} ......")
        oof = np.load(f"{dataset_folder}/{oof_filename}")

        if oof.shape[0] == 23814:
            oof = oof[non_control_group_rows, :]

        all_oof[i, :, :] = oof

        oof_loss = mean_logloss(oof, y_true)
        print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")
        model_oofs.append(oof)

    tol = 1e-10
    init_guess = [1 / all_oof.shape[0]] * all_oof.shape[0]
    bnds = [(0, 1) for _ in range(all_oof.shape[0])]
    cons = {
        'type': 'eq',
        'fun': lambda x: np.sum(x) - 1,
        'jac': lambda x: [1] * len(x)
    }

    print('Inital Blend OOF:', func_numpy_metric(init_guess))

    start_time = time.time()
    res_scipy = minimize(
        fun=func_numpy_metric,
        x0=init_guess,
        method='SLSQP',
        # jac=grad_func_jit,  # grad_func
        bounds=bnds,
        constraints=cons,
        tol=tol)
    print("\n[Scipy SLSQP]")
    print(
        f'[{str(datetime.timedelta(seconds = time.time() - start_time))[2:7]}] Optimised Blend OOF:',
        res_scipy.fun)
    print(f'Optimised Weights: {res_scipy.x}\n')

    if run_submit_script:
        submission = run_inference_scripts(submission, weights=res_scipy.x)

# Target-wise Weight Optimization #

elif method == "scipy_per_target":
    if search_mode:
        print("[Scipy SLSQP]")
        # Optimise Blending Weights with Bonus
        # https://www.kaggle.com/gogo827jz/optimise-blending-weights-with-bonus-0/notebook
        model_oofs = []
        y_true = non_control_group_train_labels[train_classes].values

        all_oof = np.zeros(
            (len(model_list), non_control_group_train_labels.shape[0], 206))
        print(all_oof.shape)
        for i, (script, oof_filename, output_filename,
                weight) in enumerate(model_list):
            print(f"Loading OOF from {oof_filename} ......")
            oof = np.load(f"{dataset_folder}/{oof_filename}")

            if oof.shape[0] == 23814:
                oof = oof[non_control_group_rows, :]

            all_oof[i, :, :] = oof

            oof_loss = mean_logloss(oof, y_true)
            print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")
            model_oofs.append(oof)

        print("\n[Scipy SLSQP Per Target]")
        optimized_target_weights = []
        for i, target in enumerate(train_classes):
            tol = 1e-10
            init_guess = [1 / all_oof.shape[0]] * all_oof.shape[0]
            bnds = [(0, 1) for _ in range(all_oof.shape[0])]
            cons = {
                'type': 'eq',
                'fun': lambda x: np.sum(x) - 1,
                'jac': lambda x: [1] * len(x)
            }

            def func_numpy_metric_targes(weights):
                oof_blend = np.tensordot(weights,
                                         all_oof[:, :, i],
                                         axes=((0), (0)))
                return log_loss_numpy(oof_blend, y_true[:, i])

            start_time = time.time()
            res_scipy = minimize(
                fun=func_numpy_metric_targes,
                x0=init_guess,
                method='SLSQP',
                # jac=grad_func_jit,  # grad_func
                bounds=bnds,
                constraints=cons,
                tol=tol)

            print(
                f'[{str(datetime.timedelta(seconds = time.time() - start_time))[2:7]}] ' + \
                f'Optimised Blend OOF for {target}:', res_scipy.fun)
            print(f'Optimised Weights for {target}: {res_scipy.x}\n')
            optimized_target_weights.append(res_scipy.x)

        blend_targets_oof = np.zeros(
            (non_control_group_train_labels.shape[0], 206))
        for i, (script, oof_filename, output_filename,
                weight) in enumerate(model_list):
            print(f"Loading OOF from {oof_filename} ......")
            oof = np.load(f"{dataset_folder}/{oof_filename}")

            if oof.shape[0] == 23814:
                oof = oof[non_control_group_rows, :]

            for j in range(206):
                blend_targets_oof[:,
                                  j] += oof[:,
                                            j] * optimized_target_weights[j][i]

            oof_loss = mean_logloss(oof, y_true)
            print(f"OOF Validation Loss of {script}: {oof_loss:.6f}\n")

        blend_targets_oof_loss = mean_logloss(blend_targets_oof, y_true)
        print(
            f"Blend Target-Wise OOF Validation Loss: {blend_targets_oof_loss:.6f}\n"
        )

        # Save optimized weights per target
        save_pickle(optimized_target_weights, model_path,
                    f"{study_name}_{blend_targets_oof_loss}")
    else:
        weights_path = glob.glob(f'{model_path}/{study_name}_*.pkl')[0]
        print(
            f"Loading target-wise optimized weights from {weights_path} ......"
        )
        optimized_target_weights = load_pickle(weights_path)

    if run_submit_script:
        # For 206 target weights
        submission = run_inference_scripts(
            submission, target_weights=optimized_target_weights)
# Out:
# [Scipy SLSQP]
# (4, 21948, 206)
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_2stageNN_ns_oldcv.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/2stageNN_with_ns_oldcv.py: 0.015606
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_script_simpleNN_oldcv.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/script_simpleNN_oldcv.py: 0.015846
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_deepinsight_efficientnet_lightning_v7_b3_0.01850.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/deepinsight_efficientnet_lightning_v7_b3_infer.py: 0.016016
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_deepinsight_ResNeSt_v2_resnest50_0.01854.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/deepinsight_resnest_lightning_v2_infer.py: 0.015756
#
#
# [Scipy SLSQP Per Target]
# [00:00] Optimised Blend OOF for 5-alpha_reductase_inhibitor: 0.00534908494825336
# Optimised Weights for 5-alpha_reductase_inhibitor: [7.31185043e-02 0.00000000e+00 9.26881496e-01 9.32413868e-18]
#
# [00:00] Optimised Blend OOF for 11-beta-hsd1_inhibitor: 0.006129377824939072
# Optimised Weights for 11-beta-hsd1_inhibitor: [3.40439482e-17 3.31189054e-16 3.77387396e-01 6.22612604e-01]
#
# [00:00] Optimised Blend OOF for acat_inhibitor: 0.007892376208073228
# Optimised Weights for acat_inhibitor: [0.00000000e+00 2.20784731e-17 3.68673280e-01 6.31326720e-01]
#
# [00:00] Optimised Blend OOF for acetylcholine_receptor_agonist: 0.04630176305957293
# Optimised Weights for acetylcholine_receptor_agonist: [0.28153496 0.22105365 0.10254067 0.39487072]
#
# [00:00] Optimised Blend OOF for acetylcholine_receptor_antagonist: 0.0678575894571391
# Optimised Weights for acetylcholine_receptor_antagonist: [0.24035698 0.19081849 0.097873   0.47095153]
#
# [00:00] Optimised Blend OOF for acetylcholinesterase_inhibitor: 0.02133258277274972
# Optimised Weights for acetylcholinesterase_inhibitor: [4.98732999e-17 6.14668784e-01 0.00000000e+00 3.85331216e-01]
#
# [00:00] Optimised Blend OOF for adenosine_receptor_agonist: 0.015513467435094916
# Optimised Weights for adenosine_receptor_agonist: [0.21497833 0.         0.41854842 0.36647325]
#
# [00:00] Optimised Blend OOF for adenosine_receptor_antagonist: 0.025135894768592248
# Optimised Weights for adenosine_receptor_antagonist: [0.39113975 0.         0.23852339 0.37033685]
#
# [00:00] Optimised Blend OOF for adenylyl_cyclase_activator: 0.001429891193170478
# Optimised Weights for adenylyl_cyclase_activator: [0.23497636 0.12310886 0.         0.64191478]
#
# [00:00] Optimised Blend OOF for adrenergic_receptor_agonist: 0.05179784982015142
# Optimised Weights for adrenergic_receptor_agonist: [0.75510405 0.19338802 0.03291862 0.01858931]
#
# [00:00] Optimised Blend OOF for adrenergic_receptor_antagonist: 0.07869785634744372
# Optimised Weights for adrenergic_receptor_antagonist: [0.40646662 0.16906572 0.22189454 0.20257312]
#
# [00:00] Optimised Blend OOF for akt_inhibitor: 0.009398910225792227
# Optimised Weights for akt_inhibitor: [0.46420062 0.12281461 0.06797296 0.34501181]
#
# [00:00] Optimised Blend OOF for aldehyde_dehydrogenase_inhibitor: 0.001195352404272915
# Optimised Weights for aldehyde_dehydrogenase_inhibitor: [1.00000000e+00 0.00000000e+00 1.38777878e-17 5.55111512e-17]
#
# [00:00] Optimised Blend OOF for alk_inhibitor: 0.008125715741934185
# Optimised Weights for alk_inhibitor: [0.         0.00332533 0.42133996 0.57533471]
#
# [00:00] Optimised Blend OOF for ampk_activator: 0.004560593622540136
# Optimised Weights for ampk_activator: [0.00000000e+00 5.42647343e-17 0.00000000e+00 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for analgesic: 0.00444175773918841
# Optimised Weights for analgesic: [0.         0.         0.27888593 0.72111407]
#
# [00:00] Optimised Blend OOF for androgen_receptor_agonist: 0.014503417394924438
# Optimised Weights for androgen_receptor_agonist: [0.08782336 0.         0.2413498  0.67082683]
#
# [00:00] Optimised Blend OOF for androgen_receptor_antagonist: 0.024672536580347446
# Optimised Weights for androgen_receptor_antagonist: [0.35376452 0.12709065 0.17703556 0.34210927]
#
# [00:00] Optimised Blend OOF for anesthetic_-_local: 0.022891583400341194
# Optimised Weights for anesthetic_-_local: [3.38474681e-01 9.93352842e-05 2.49580054e-01 4.11845930e-01]
#
# [00:00] Optimised Blend OOF for angiogenesis_inhibitor: 0.011044337618837226
# Optimised Weights for angiogenesis_inhibitor: [0.00000000e+00 6.60926340e-18 2.60753691e-01 7.39246309e-01]
#
# [00:00] Optimised Blend OOF for angiotensin_receptor_antagonist: 0.01176790393877765
# Optimised Weights for angiotensin_receptor_antagonist: [3.95646017e-01 5.91161235e-17 2.81052413e-01 3.23301570e-01]
#
# [00:00] Optimised Blend OOF for anti-inflammatory: 0.01965489645930277
# Optimised Weights for anti-inflammatory: [0.11482212 0.         0.36850235 0.51667553]
#
# [00:00] Optimised Blend OOF for antiarrhythmic: 0.0024941879627830205
# Optimised Weights for antiarrhythmic: [0.00000000e+00 0.00000000e+00 2.77555756e-16 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for antibiotic: 0.011437179709564595
# Optimised Weights for antibiotic: [3.99797879e-01 6.75254666e-17 3.53500031e-01 2.46702090e-01]
#
# [00:00] Optimised Blend OOF for anticonvulsant: 0.004521458800560968
# Optimised Weights for anticonvulsant: [6.58652820e-17 1.23208735e-01 1.23458023e-01 7.53333242e-01]
#
# [00:00] Optimised Blend OOF for antifungal: 0.004399019804039901
# Optimised Weights for antifungal: [0.00000000e+00 2.36195908e-16 1.78579379e-01 8.21420621e-01]
#
# [00:00] Optimised Blend OOF for antihistamine: 0.0043710580810324496
# Optimised Weights for antihistamine: [0.         0.         0.45093747 0.54906253]
#
# [00:00] Optimised Blend OOF for antimalarial: 0.0057727533104485595
# Optimised Weights for antimalarial: [0.00000000e+00 1.38777878e-17 4.97351946e-01 5.02648054e-01]
#
# [00:00] Optimised Blend OOF for antioxidant: 0.021081839837799776
# Optimised Weights for antioxidant: [2.25782015e-01 1.34441069e-17 2.58078734e-01 5.16139251e-01]
#
# [00:00] Optimised Blend OOF for antiprotozoal: 0.011405740732121543
# Optimised Weights for antiprotozoal: [8.16641405e-17 2.03696933e-17 4.88628750e-01 5.11371250e-01]
#
# [00:00] Optimised Blend OOF for antiviral: 0.008056435477320635
# Optimised Weights for antiviral: [0.21221188 0.         0.         0.78778812]
#
# [00:00] Optimised Blend OOF for apoptosis_stimulant: 0.013408100425086441
# Optimised Weights for apoptosis_stimulant: [5.71514954e-01 2.10064171e-18 2.04168822e-16 4.28485046e-01]
#
# [00:00] Optimised Blend OOF for aromatase_inhibitor: 0.014546281024049274
# Optimised Weights for aromatase_inhibitor: [1.91090633e-17 4.23716286e-01 4.52917324e-01 1.23366390e-01]
#
# [00:00] Optimised Blend OOF for atm_kinase_inhibitor: 0.00176826350372471
# Optimised Weights for atm_kinase_inhibitor: [4.25007252e-17 2.11614741e-17 2.74721632e-02 9.72527837e-01]
#
# [00:00] Optimised Blend OOF for atp-sensitive_potassium_channel_antagonist: 0.0008503033082407638
# Optimised Weights for atp-sensitive_potassium_channel_antagonist: [2.77555756e-16 0.00000000e+00 0.00000000e+00 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for atp_synthase_inhibitor: 0.0010510450652888809
# Optimised Weights for atp_synthase_inhibitor: [0.        0.        0.6415708 0.3584292]
#
# [00:00] Optimised Blend OOF for atpase_inhibitor: 0.019703165386654942
# Optimised Weights for atpase_inhibitor: [5.81829357e-01 5.42101086e-20 1.81335621e-01 2.36835023e-01]
#
# [00:00] Optimised Blend OOF for atr_kinase_inhibitor: 0.002670485292070491
# Optimised Weights for atr_kinase_inhibitor: [0.29575363 0.         0.         0.70424637]
#
# [00:00] Optimised Blend OOF for aurora_kinase_inhibitor: 0.007809177406692234
# Optimised Weights for aurora_kinase_inhibitor: [0.25375219 0.12429432 0.21233338 0.40962011]
#
# [00:00] Optimised Blend OOF for autotaxin_inhibitor: 0.0021920319451652023
# Optimised Weights for autotaxin_inhibitor: [0.         0.         0.94072066 0.05927934]
#
# [00:00] Optimised Blend OOF for bacterial_30s_ribosomal_subunit_inhibitor: 0.01762743533564689
# Optimised Weights for bacterial_30s_ribosomal_subunit_inhibitor: [0.1988405  0.12455352 0.20765664 0.46894934]
#
# [00:00] Optimised Blend OOF for bacterial_50s_ribosomal_subunit_inhibitor: 0.02127981784751936
# Optimised Weights for bacterial_50s_ribosomal_subunit_inhibitor: [0.07682068 0.13751237 0.26236595 0.523301  ]
# [00:00] Optimised Blend OOF for bacterial_antifolate: 0.011215431123959617
# Optimised Weights for bacterial_antifolate: [0.         0.69979182 0.27812483 0.02208334]
#
# [00:00] Optimised Blend OOF for bacterial_cell_wall_synthesis_inhibitor: 0.04718507832835445
# Optimised Weights for bacterial_cell_wall_synthesis_inhibitor: [0.33318577 0.         0.24838685 0.41842739]
#
# [00:00] Optimised Blend OOF for bacterial_dna_gyrase_inhibitor: 0.024431103225764774
# Optimised Weights for bacterial_dna_gyrase_inhibitor: [0.30683044 0.1283045  0.12238081 0.44248424]
#
# [00:00] Optimised Blend OOF for bacterial_dna_inhibitor: 0.029955790629390508
# Optimised Weights for bacterial_dna_inhibitor: [4.33305524e-01 4.83825219e-18 2.13203459e-01 3.53491016e-01]
#
# [00:00] Optimised Blend OOF for bacterial_membrane_integrity_inhibitor: 0.0013956562058146862
# Optimised Weights for bacterial_membrane_integrity_inhibitor: [4.16333634e-16 0.00000000e+00 0.00000000e+00 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for bcl_inhibitor: 0.007435859774517504
# Optimised Weights for bcl_inhibitor: [2.62790571e-01 3.25396177e-17 2.64955980e-01 4.72253449e-01]
#
# [00:00] Optimised Blend OOF for bcr-abl_inhibitor: 0.006426877468292729
# Optimised Weights for bcr-abl_inhibitor: [3.30971248e-01 1.65574612e-16 1.04717010e-01 5.64311742e-01]
#
# [00:00] Optimised Blend OOF for benzodiazepine_receptor_agonist: 0.019178393377211257
# Optimised Weights for benzodiazepine_receptor_agonist: [2.20678447e-01 2.72405796e-18 4.10820019e-01 3.68501534e-01]
#
# [00:00] Optimised Blend OOF for beta_amyloid_inhibitor: 0.00851323926227356
# Optimised Weights for beta_amyloid_inhibitor: [0.369588   0.25675869 0.37365331 0.        ]
#
# [00:00] Optimised Blend OOF for bromodomain_inhibitor: 0.012087329533246061
# Optimised Weights for bromodomain_inhibitor: [0.23730202 0.52883489 0.23386309 0.        ]
#
# [00:00] Optimised Blend OOF for btk_inhibitor: 0.006303539895324052
# Optimised Weights for btk_inhibitor: [1.24074277e-01 1.00288701e-18 4.13895936e-01 4.62029787e-01]
#
# [00:00] Optimised Blend OOF for calcineurin_inhibitor: 0.0025426916843014485
# Optimised Weights for calcineurin_inhibitor: [3.60822483e-16 1.16215796e-16 8.32667268e-17 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for calcium_channel_blocker: 0.06216603005243252
# Optimised Weights for calcium_channel_blocker: [0.43461146 0.2115384  0.15173157 0.20211856]
#
# [00:00] Optimised Blend OOF for cannabinoid_receptor_agonist: 0.012524245574892979
# Optimised Weights for cannabinoid_receptor_agonist: [1.30865890e-01 6.12574227e-18 1.28650309e-01 7.40483801e-01]
#
# [00:00] Optimised Blend OOF for cannabinoid_receptor_antagonist: 0.016012618114737743
# Optimised Weights for cannabinoid_receptor_antagonist: [4.87890978e-19 2.46420771e-01 1.16402703e-01 6.37176526e-01]
#
# [00:00] Optimised Blend OOF for carbonic_anhydrase_inhibitor: 0.011728489302800559
# Optimised Weights for carbonic_anhydrase_inhibitor: [0.34642707 0.50120277 0.         0.15237016]
#
# [00:00] Optimised Blend OOF for casein_kinase_inhibitor: 0.010106733258140004
# Optimised Weights for casein_kinase_inhibitor: [7.2858386e-17 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#
# [00:00] Optimised Blend OOF for caspase_activator: 0.006404102931849689
# Optimised Weights for caspase_activator: [0.36710926 0.         0.21395443 0.41893631]
#
# [00:00] Optimised Blend OOF for catechol_o_methyltransferase_inhibitor: 0.004789257026789473
# Optimised Weights for catechol_o_methyltransferase_inhibitor: [0.35943149 0.45000086 0.15293628 0.03763137]
#
# [00:00] Optimised Blend OOF for cc_chemokine_receptor_antagonist: 0.027878766761524326
# Optimised Weights for cc_chemokine_receptor_antagonist: [0.00714958 0.25454978 0.44480036 0.29350028]
#
# [00:00] Optimised Blend OOF for cck_receptor_antagonist: 0.0065842654470313474
# Optimised Weights for cck_receptor_antagonist: [3.76416442e-01 2.30121911e-17 5.95253656e-01 2.83299027e-02]
#
# [00:00] Optimised Blend OOF for cdk_inhibitor: 0.015079341523034666
# Optimised Weights for cdk_inhibitor: [0.22446913 0.20034526 0.39126001 0.1839256 ]
#
# [00:00] Optimised Blend OOF for chelating_agent: 0.01634918267408124
# Optimised Weights for chelating_agent: [5.59102912e-01 1.74556550e-17 4.40897088e-01 1.08420217e-18]
#
# [00:00] Optimised Blend OOF for chk_inhibitor: 0.00169257313728187
# Optimised Weights for chk_inhibitor: [0.35345938 0.         0.62095526 0.02558536]
#
# [00:00] Optimised Blend OOF for chloride_channel_blocker: 0.01279882075121948
# Optimised Weights for chloride_channel_blocker: [6.29485720e-01 4.75720808e-16 2.02534129e-01 1.67980151e-01]
#
# [00:00] Optimised Blend OOF for cholesterol_inhibitor: 0.015036795951253552
# Optimised Weights for cholesterol_inhibitor: [0.3157854  0.33529215 0.         0.34892245]
#
# [00:00] Optimised Blend OOF for cholinergic_receptor_antagonist: 0.015967895258781232
# Optimised Weights for cholinergic_receptor_antagonist: [0.17924687 0.         0.47695363 0.3437995 ]
#
# [00:00] Optimised Blend OOF for coagulation_factor_inhibitor: 0.0025581008806925105
# Optimised Weights for coagulation_factor_inhibitor: [0.00000000e+00 0.00000000e+00 2.22044605e-16 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for corticosteroid_agonist: 0.008127954419166191
# Optimised Weights for corticosteroid_agonist: [2.75387352e-17 2.75362045e-02 3.42704339e-01 6.29759456e-01]
#
# [00:00] Optimised Blend OOF for cyclooxygenase_inhibitor: 0.08809078542206211
# Optimised Weights for cyclooxygenase_inhibitor: [0.36700026 0.32891493 0.04697139 0.25711341]
#
# [00:00] Optimised Blend OOF for cytochrome_p450_inhibitor: 0.027621909336979424
# Optimised Weights for cytochrome_p450_inhibitor: [0.35619848 0.05200227 0.25613534 0.33566391]
#
# [00:00] Optimised Blend OOF for dihydrofolate_reductase_inhibitor: 0.007696847200001889
# Optimised Weights for dihydrofolate_reductase_inhibitor: [5.55111512e-17 1.00000000e+00 1.73472348e-17 4.51028104e-17]
#
# [00:00] Optimised Blend OOF for dipeptidyl_peptidase_inhibitor: 0.008225998312981264
# Optimised Weights for dipeptidyl_peptidase_inhibitor: [0.15093071 0.         0.57718158 0.27188771]
#
# [00:00] Optimised Blend OOF for diuretic: 0.0025441975164069595
# Optimised Weights for diuretic: [0.         0.         0.12540411 0.87459589]
#
# [00:00] Optimised Blend OOF for dna_alkylating_agent: 0.014480895425509595
# Optimised Weights for dna_alkylating_agent: [0.32402969 0.         0.05855428 0.61741603]
#
# [00:00] Optimised Blend OOF for dna_inhibitor: 0.07625020142921071
# Optimised Weights for dna_inhibitor: [0.47220225 0.26842549 0.13198457 0.12738769]
#
# [00:00] Optimised Blend OOF for dopamine_receptor_agonist: 0.031282499306459446
# Optimised Weights for dopamine_receptor_agonist: [0.03465522 0.03995942 0.44686101 0.47852435]
#
# [00:00] Optimised Blend OOF for dopamine_receptor_antagonist: 0.08425236986468454
# Optimised Weights for dopamine_receptor_antagonist: [0.24075066 0.3111218  0.12972693 0.31840061]
#
# [00:00] Optimised Blend OOF for egfr_inhibitor: 0.012911410860840324
# Optimised Weights for egfr_inhibitor: [0.54876457 0.00480823 0.1856553  0.2607719 ]
#
# [00:00] Optimised Blend OOF for elastase_inhibitor: 0.0024685928864434307
# Optimised Weights for elastase_inhibitor: [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.66533454e-16]
#
# [00:00] Optimised Blend OOF for erbb2_inhibitor: 0.0008583838722033388
# Optimised Weights for erbb2_inhibitor: [0.00000000e+00 1.17787148e-16 1.00000000e+00 5.55111512e-16]
#
# [00:00] Optimised Blend OOF for estrogen_receptor_agonist: 0.038782606516380914
# Optimised Weights for estrogen_receptor_agonist: [0.41922257 0.17108901 0.23290785 0.17678057]
#
# [00:00] Optimised Blend OOF for estrogen_receptor_antagonist: 0.013507976379391601
# Optimised Weights for estrogen_receptor_antagonist: [6.23134366e-01 1.51788304e-17 1.40236391e-01 2.36629242e-01]
#
# [00:00] Optimised Blend OOF for faah_inhibitor: 0.009895515007202791
# Optimised Weights for faah_inhibitor: [7.80625564e-18 6.23553562e-02 3.35663125e-01 6.01981518e-01]
#
# [00:00] Optimised Blend OOF for farnesyltransferase_inhibitor: 0.002276140332366883
# Optimised Weights for farnesyltransferase_inhibitor: [1.52883168e-01 5.67850888e-18 6.53179541e-01 1.93937291e-01]
#
# [00:00] Optimised Blend OOF for fatty_acid_receptor_agonist: 0.008218910936285526
# Optimised Weights for fatty_acid_receptor_agonist: [1.79977561e-17 6.43914801e-01 1.99284288e-01 1.56800911e-01]
# [00:00] Optimised Blend OOF for fgfr_inhibitor: 0.008160519981535224
# Optimised Weights for fgfr_inhibitor: [0.12714774 0.0972131  0.07239985 0.70323931]
#
# [00:00] Optimised Blend OOF for flt3_inhibitor: 0.014245457245188494
# Optimised Weights for flt3_inhibitor: [0.39071676 0.05996004 0.23330219 0.31602101]
#
# [00:00] Optimised Blend OOF for focal_adhesion_kinase_inhibitor: 0.0010952254980181387
# Optimised Weights for focal_adhesion_kinase_inhibitor: [1.06685494e-16 0.00000000e+00 6.49968020e-01 3.50031980e-01]
#
# [00:00] Optimised Blend OOF for free_radical_scavenger: 0.006334600199299149
# Optimised Weights for free_radical_scavenger: [2.49366500e-17 3.16311177e-02 0.00000000e+00 9.68368882e-01]
#
# [00:00] Optimised Blend OOF for fungal_squalene_epoxidase_inhibitor: 0.006125076372076435
# Optimised Weights for fungal_squalene_epoxidase_inhibitor: [0.         0.         0.48423913 0.51576087]
#
# [00:00] Optimised Blend OOF for gaba_receptor_agonist: 0.0279619913020012
# Optimised Weights for gaba_receptor_agonist: [0.18391054 0.01315555 0.40740787 0.39552604]
#
# [00:00] Optimised Blend OOF for gaba_receptor_antagonist: 0.04125492008756603
# Optimised Weights for gaba_receptor_antagonist: [0.41017993 0.00311368 0.17534522 0.41136117]
#
# [00:00] Optimised Blend OOF for gamma_secretase_inhibitor: 0.008585854561974332
# Optimised Weights for gamma_secretase_inhibitor: [0.18863346 0.42105909 0.12922423 0.26108321]
#
# [00:00] Optimised Blend OOF for glucocorticoid_receptor_agonist: 0.013677539313666885
# Optimised Weights for glucocorticoid_receptor_agonist: [0.         0.33888319 0.25178274 0.40933408]
#
# [00:00] Optimised Blend OOF for glutamate_inhibitor: 0.004292204663051095
# Optimised Weights for glutamate_inhibitor: [0.00000000e+00 0.00000000e+00 1.00000000e+00 4.16333634e-17]
#
# [00:00] Optimised Blend OOF for glutamate_receptor_agonist: 0.021532800537791264
# Optimised Weights for glutamate_receptor_agonist: [0.28369468 0.06775946 0.19561027 0.45293559]
#
# [00:00] Optimised Blend OOF for glutamate_receptor_antagonist: 0.08040940773847897
# Optimised Weights for glutamate_receptor_antagonist: [8.93678464e-01 4.52654407e-18 6.79192088e-02 3.84023268e-02]
#
# [00:00] Optimised Blend OOF for gonadotropin_receptor_agonist: 0.006237574854452457
# Optimised Weights for gonadotropin_receptor_agonist: [0.00000000e+00 2.16519138e-16 1.09199722e-01 8.90800278e-01]
#
# [00:00] Optimised Blend OOF for gsk_inhibitor: 0.008837615016549168
# Optimised Weights for gsk_inhibitor: [1.03371901e-17 3.51244866e-01 1.78630043e-02 6.30892130e-01]
#
# [00:00] Optimised Blend OOF for hcv_inhibitor: 0.0206023216623446
# Optimised Weights for hcv_inhibitor: [4.12925484e-01 1.88109077e-17 3.10275880e-01 2.76798635e-01]
#
# [00:00] Optimised Blend OOF for hdac_inhibitor: 0.009543402670511568
# Optimised Weights for hdac_inhibitor: [0.12949381 0.46150455 0.01299056 0.39601108]
#
# [00:00] Optimised Blend OOF for histamine_receptor_agonist: 0.01774048429403757
# Optimised Weights for histamine_receptor_agonist: [4.01696905e-17 3.08989285e-01 4.21934932e-01 2.69075783e-01]
#
# [00:00] Optimised Blend OOF for histamine_receptor_antagonist: 0.05686654220980801
# Optimised Weights for histamine_receptor_antagonist: [0.22381219 0.30680775 0.22070712 0.24867294]
#
# [00:00] Optimised Blend OOF for histone_lysine_demethylase_inhibitor: 0.004185570122177158
# Optimised Weights for histone_lysine_demethylase_inhibitor: [0.8852565 0.1147435 0.        0.       ]
#
# [00:00] Optimised Blend OOF for histone_lysine_methyltransferase_inhibitor: 0.009231030079801432
# Optimised Weights for histone_lysine_methyltransferase_inhibitor: [7.96036953e-02 8.52990467e-01 1.03812358e-17 6.74058382e-02]
#
# [00:00] Optimised Blend OOF for hiv_inhibitor: 0.019892265104045754
# Optimised Weights for hiv_inhibitor: [4.20774322e-01 8.45677695e-18 9.47853982e-02 4.84440280e-01]
#
# [00:00] Optimised Blend OOF for hmgcr_inhibitor: 0.007925669250958743
# Optimised Weights for hmgcr_inhibitor: [0.14871361 0.14322105 0.4791297  0.22893564]
#
# [00:00] Optimised Blend OOF for hsp_inhibitor: 0.006860246496123566
# Optimised Weights for hsp_inhibitor: [4.36839657e-01 4.11454724e-17 1.26228046e-01 4.36932296e-01]
#
# [00:00] Optimised Blend OOF for igf-1_inhibitor: 0.007319965695645778
# Optimised Weights for igf-1_inhibitor: [4.44200834e-01 1.09456043e-01 3.60497222e-17 4.46343123e-01]
#
# [00:00] Optimised Blend OOF for ikk_inhibitor: 0.0059338835044291565
# Optimised Weights for ikk_inhibitor: [0.16241998 0.00547411 0.15785138 0.67425453]
#
# [00:00] Optimised Blend OOF for imidazoline_receptor_agonist: 0.010307717769693603
# Optimised Weights for imidazoline_receptor_agonist: [0.        0.1585273 0.4808503 0.3606224]
#
# [00:00] Optimised Blend OOF for immunosuppressant: 0.01687868951814197
# Optimised Weights for immunosuppressant: [0.24233879 0.         0.12465148 0.63300973]
#
# [00:00] Optimised Blend OOF for insulin_secretagogue: 0.010003169994749426
# Optimised Weights for insulin_secretagogue: [2.68407800e-17 5.86956294e-01 3.51849635e-01 6.11940710e-02]
#
# [00:00] Optimised Blend OOF for insulin_sensitizer: 0.010540061218160092
# Optimised Weights for insulin_sensitizer: [0.32585844 0.04786802 0.14479062 0.48148292]
#
# [00:00] Optimised Blend OOF for integrin_inhibitor: 0.012416758991990668
# Optimised Weights for integrin_inhibitor: [0.41655605 0.         0.06395427 0.51948968]
#
# [00:00] Optimised Blend OOF for jak_inhibitor: 0.008908862566818596
# Optimised Weights for jak_inhibitor: [0.31406321 0.16397221 0.21550351 0.30646107]
#
# [00:00] Optimised Blend OOF for kit_inhibitor: 0.012786703303129055
# Optimised Weights for kit_inhibitor: [0.36574509 0.01542583 0.2580051  0.36082398]
#
# [00:00] Optimised Blend OOF for laxative: 0.0026125561170491133
# Optimised Weights for laxative: [1.66533454e-16 0.00000000e+00 1.38777878e-17 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for leukotriene_inhibitor: 0.002589957538823887
# Optimised Weights for leukotriene_inhibitor: [0.00000000e+00 4.03885328e-16 1.34087399e-01 8.65912601e-01]
#
# [00:00] Optimised Blend OOF for leukotriene_receptor_antagonist: 0.01775089414687006
# Optimised Weights for leukotriene_receptor_antagonist: [3.13923708e-01 4.61870125e-17 3.46944695e-18 6.86076292e-01]
#
# [00:00] Optimised Blend OOF for lipase_inhibitor: 0.0046137034785951915
# Optimised Weights for lipase_inhibitor: [2.94902991e-17 0.00000000e+00 3.62210859e-17 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for lipoxygenase_inhibitor: 0.016493379226681003
# Optimised Weights for lipoxygenase_inhibitor: [1.40213172e-01 9.45288769e-19 1.95381695e-01 6.64405134e-01]
#
# [00:00] Optimised Blend OOF for lxr_agonist: 0.0015141245116441831
# Optimised Weights for lxr_agonist: [0.00000000e+00 1.13200761e-16 2.22437927e-01 7.77562073e-01]
#
# [00:00] Optimised Blend OOF for mdm_inhibitor: 0.003021341936687862
# Optimised Weights for mdm_inhibitor: [6.65346346e-01 1.03812358e-17 1.31358714e-02 3.21517783e-01]
#
# [00:00] Optimised Blend OOF for mek_inhibitor: 0.00575624453708794
# Optimised Weights for mek_inhibitor: [0.20068283 0.         0.40996136 0.38935581]
#
# [00:00] Optimised Blend OOF for membrane_integrity_inhibitor: 0.02038762472019851
# Optimised Weights for membrane_integrity_inhibitor: [0.03427692 0.05569669 0.56341991 0.34660648]
#
# [00:00] Optimised Blend OOF for mineralocorticoid_receptor_antagonist: 0.00818560474156273
# Optimised Weights for mineralocorticoid_receptor_antagonist: [0.10950921 0.21437525 0.12481739 0.55129815]
#
# [00:00] Optimised Blend OOF for monoacylglycerol_lipase_inhibitor: 0.004519006622792499
# Optimised Weights for monoacylglycerol_lipase_inhibitor: [7.05273513e-17 0.00000000e+00 2.96004591e-01 7.03995409e-01]
#
# [00:00] Optimised Blend OOF for monoamine_oxidase_inhibitor: 0.024180680499733286
# Optimised Weights for monoamine_oxidase_inhibitor: [0.56125612 0.         0.18876722 0.24997666]
#
# [00:00] Optimised Blend OOF for monopolar_spindle_1_kinase_inhibitor: 0.004773491007684698
# Optimised Weights for monopolar_spindle_1_kinase_inhibitor: [0.25086537 0.         0.58574847 0.16338617]
#
# [00:00] Optimised Blend OOF for mtor_inhibitor: 0.01314812442643496
# Optimised Weights for mtor_inhibitor: [0.547346   0.03112823 0.3380195  0.08350626]
#
# [00:00] Optimised Blend OOF for mucolytic_agent: 0.014869534775054814
# Optimised Weights for mucolytic_agent: [0.64702711 0.         0.05393889 0.299034  ]
# [00:00] Optimised Blend OOF for neuropeptide_receptor_antagonist: 0.011161594073882604
# Optimised Weights for neuropeptide_receptor_antagonist: [2.69412392e-01 2.60208521e-18 9.69900329e-02 6.33597575e-01]
#
# [00:00] Optimised Blend OOF for nfkb_inhibitor: 0.02920228590672476
# Optimised Weights for nfkb_inhibitor: [0.15296167 0.15519267 0.36738517 0.3244605 ]
#
# [00:00] Optimised Blend OOF for nicotinic_receptor_agonist: 0.0025659259397594015
# Optimised Weights for nicotinic_receptor_agonist: [4.16333634e-17 2.68606813e-17 1.00000000e+00 0.00000000e+00]
#
# [00:00] Optimised Blend OOF for nitric_oxide_donor: 0.008481725447741704
# Optimised Weights for nitric_oxide_donor: [2.71050543e-18 0.00000000e+00 3.85128372e-01 6.14871628e-01]
#
# [00:00] Optimised Blend OOF for nitric_oxide_production_inhibitor: 0.003419250080484674
# Optimised Weights for nitric_oxide_production_inhibitor: [2.45546519e-01 4.02645582e-17 2.71744695e-01 4.82708785e-01]
#
# [00:00] Optimised Blend OOF for nitric_oxide_synthase_inhibitor: 0.00881828518438008
# Optimised Weights for nitric_oxide_synthase_inhibitor: [0.31954794 0.33210338 0.         0.34834868]
#
# [00:00] Optimised Blend OOF for norepinephrine_reuptake_inhibitor: 0.0029042814498655427
# Optimised Weights for norepinephrine_reuptake_inhibitor: [0.00000000e+00 3.62081560e-16 2.34571050e-02 9.76542895e-01]
#
# [00:00] Optimised Blend OOF for nrf2_activator: 0.0038139135659354664
# Optimised Weights for nrf2_activator: [1.32870182e-01 1.35525272e-17 4.51163781e-01 4.15966036e-01]
#
# [00:00] Optimised Blend OOF for opioid_receptor_agonist: 0.0181571321980277
# Optimised Weights for opioid_receptor_agonist: [0.24164982 0.06367782 0.41379334 0.28087903]
#
# [00:00] Optimised Blend OOF for opioid_receptor_antagonist: 0.02608846878619548
# Optimised Weights for opioid_receptor_antagonist: [0.49620707 0.         0.07499111 0.42880182]
#
# [00:00] Optimised Blend OOF for orexin_receptor_antagonist: 0.011694252918961054
# Optimised Weights for orexin_receptor_antagonist: [0.06517389 0.         0.28582551 0.6490006 ]
#
# [00:00] Optimised Blend OOF for p38_mapk_inhibitor: 0.007495400053637544
# Optimised Weights for p38_mapk_inhibitor: [0.15499675 0.15736708 0.0762295  0.61140668]
#
# [00:00] Optimised Blend OOF for p-glycoprotein_inhibitor: 0.006931982221606631
# Optimised Weights for p-glycoprotein_inhibitor: [8.84708973e-17 1.43114687e-17 0.00000000e+00 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for parp_inhibitor: 0.01488162379974738
# Optimised Weights for parp_inhibitor: [0.45071984 0.03359264 0.24585649 0.26983103]
#
# [00:00] Optimised Blend OOF for pdgfr_inhibitor: 0.013973776521906366
# Optimised Weights for pdgfr_inhibitor: [2.53960669e-01 1.08420217e-19 2.39448344e-01 5.06590987e-01]
#
# [00:00] Optimised Blend OOF for pdk_inhibitor: 0.005641831885668179
# Optimised Weights for pdk_inhibitor: [1.72930247e-17 1.88867054e-01 1.61771753e-01 6.49361193e-01]
#
# [00:00] Optimised Blend OOF for phosphodiesterase_inhibitor: 0.05908827107101215
# Optimised Weights for phosphodiesterase_inhibitor: [0.5792855  0.11421599 0.2030718  0.10342671]
#
# [00:00] Optimised Blend OOF for phospholipase_inhibitor: 0.00828775176207125
# Optimised Weights for phospholipase_inhibitor: [4.85722573e-17 0.00000000e+00 4.87960678e-01 5.12039322e-01]
#
# [00:00] Optimised Blend OOF for pi3k_inhibitor: 0.021467833583666794
# Optimised Weights for pi3k_inhibitor: [0.36554914 0.23505133 0.14770887 0.25169066]
#
# [00:00] Optimised Blend OOF for pkc_inhibitor: 0.007833974007261124
# Optimised Weights for pkc_inhibitor: [0.00000000e+00 7.17356686e-17 4.33189485e-01 5.66810515e-01]
#
# [00:00] Optimised Blend OOF for potassium_channel_activator: 0.01634905673446908
# Optimised Weights for potassium_channel_activator: [0.54895039 0.         0.         0.45104961]
#
# [00:00] Optimised Blend OOF for potassium_channel_antagonist: 0.027003346244045594
# Optimised Weights for potassium_channel_antagonist: [6.17621468e-01 2.77013655e-17 0.00000000e+00 3.82378532e-01]
#
# [00:00] Optimised Blend OOF for ppar_receptor_agonist: 0.021717014299939764
# Optimised Weights for ppar_receptor_agonist: [0.34457819 0.25274542 0.15996017 0.24271623]
#
# [00:00] Optimised Blend OOF for ppar_receptor_antagonist: 0.008728709902858707
# Optimised Weights for ppar_receptor_antagonist: [0.21961634 0.02917505 0.15910836 0.59210024]
#
# [00:00] Optimised Blend OOF for progesterone_receptor_agonist: 0.026860296790336257
# Optimised Weights for progesterone_receptor_agonist: [0.39386706 0.25143943 0.19875904 0.15593447]
#
# [00:00] Optimised Blend OOF for progesterone_receptor_antagonist: 0.004621886436342591
# Optimised Weights for progesterone_receptor_antagonist: [0.         0.49574624 0.10841002 0.39584374]
#
# [00:00] Optimised Blend OOF for prostaglandin_inhibitor: 0.01160472385223534
# Optimised Weights for prostaglandin_inhibitor: [0.         0.49953301 0.36776772 0.13269927]
#
# [00:00] Optimised Blend OOF for prostanoid_receptor_antagonist: 0.023668328806759297
# Optimised Weights for prostanoid_receptor_antagonist: [2.62376926e-17 6.21824285e-01 9.88328939e-18 3.78175715e-01]
#
# [00:00] Optimised Blend OOF for proteasome_inhibitor: 0.0011288205944733586
# Optimised Weights for proteasome_inhibitor: [0.00000000e+00 1.19962793e-16 8.42797122e-01 1.57202878e-01]
#
# [00:00] Optimised Blend OOF for protein_kinase_inhibitor: 0.013985024397495395
# Optimised Weights for protein_kinase_inhibitor: [7.52794231e-02 1.14993193e-17 3.53384112e-01 5.71336465e-01]
#
# [00:00] Optimised Blend OOF for protein_phosphatase_inhibitor: 0.002066634131969846
# Optimised Weights for protein_phosphatase_inhibitor: [1.52655666e-16 6.19544619e-17 1.00000000e+00 0.00000000e+00]
#
# [00:00] Optimised Blend OOF for protein_synthesis_inhibitor: 0.021379491037281116
# Optimised Weights for protein_synthesis_inhibitor: [0.45505699 0.10897921 0.40139235 0.03457145]
#
# [00:00] Optimised Blend OOF for protein_tyrosine_kinase_inhibitor: 0.006220837395168158
# Optimised Weights for protein_tyrosine_kinase_inhibitor: [0.05246639 0.18192667 0.         0.76560693]
#
# [00:00] Optimised Blend OOF for radiopaque_medium: 0.01678724429793428
# Optimised Weights for radiopaque_medium: [4.46746735e-17 5.07584403e-01 4.92415597e-01 1.48975899e-17]
#
# [00:00] Optimised Blend OOF for raf_inhibitor: 0.004241953967294162
# Optimised Weights for raf_inhibitor: [0.52940325 0.04858575 0.34780479 0.07420621]
#
# [00:00] Optimised Blend OOF for ras_gtpase_inhibitor: 0.003538241613591447
# Optimised Weights for ras_gtpase_inhibitor: [0.00000000e+00 1.36360362e-16 2.86229374e-17 1.00000000e+00]
#
# [00:00] Optimised Blend OOF for retinoid_receptor_agonist: 0.007879057105277473
# Optimised Weights for retinoid_receptor_agonist: [0.65255484 0.28121653 0.05994946 0.00627917]
#
# [00:00] Optimised Blend OOF for retinoid_receptor_antagonist: 0.0025049025958606445
# Optimised Weights for retinoid_receptor_antagonist: [2.71484224e-16 0.00000000e+00 1.74902691e-01 8.25097309e-01]
#
# [00:00] Optimised Blend OOF for rho_associated_kinase_inhibitor: 0.007342419729795824
# Optimised Weights for rho_associated_kinase_inhibitor: [5.19924605e-01 3.28322517e-01 1.51752879e-01 1.38425512e-16]
#
# [00:00] Optimised Blend OOF for ribonucleoside_reductase_inhibitor: 0.00864297193771195
# Optimised Weights for ribonucleoside_reductase_inhibitor: [0.         0.12524102 0.3527172  0.52204178]
#
# [00:00] Optimised Blend OOF for rna_polymerase_inhibitor: 0.007898613848388622
# Optimised Weights for rna_polymerase_inhibitor: [1.87156631e-02 2.23345648e-17 0.00000000e+00 9.81284337e-01]
#
# [00:00] Optimised Blend OOF for serotonin_receptor_agonist: 0.05597317008388954
# Optimised Weights for serotonin_receptor_agonist: [4.16011190e-01 3.79470760e-19 2.47103821e-01 3.36884989e-01]
#
# [00:00] Optimised Blend OOF for serotonin_receptor_antagonist: 0.0831942668354396
# Optimised Weights for serotonin_receptor_antagonist: [0.24832206 0.19326407 0.19175822 0.36665565]
#
# [00:00] Optimised Blend OOF for serotonin_reuptake_inhibitor: 0.013270231733440907
# Optimised Weights for serotonin_reuptake_inhibitor: [0.07942932 0.16525947 0.13249462 0.62281659]
#
# [00:00] Optimised Blend OOF for sigma_receptor_agonist: 0.011861455812711953
# Optimised Weights for sigma_receptor_agonist: [0.         0.52853289 0.20771131 0.2637558 ]
#
# [00:00] Optimised Blend OOF for sigma_receptor_antagonist: 0.011556524390205011
# Optimised Weights for sigma_receptor_antagonist: [0.2386386  0.17220305 0.10500586 0.4841525 ]
# [00:00] Optimised Blend OOF for smoothened_receptor_antagonist: 0.008062846361884961
# Optimised Weights for smoothened_receptor_antagonist: [1.38777878e-17 1.67394842e-17 4.93620629e-01 5.06379371e-01]
#
# [00:00] Optimised Blend OOF for sodium_channel_inhibitor: 0.06261501134568109
# Optimised Weights for sodium_channel_inhibitor: [0.60997137 0.         0.12122892 0.26879971]
#
# [00:00] Optimised Blend OOF for sphingosine_receptor_agonist: 0.008136281824955129
# Optimised Weights for sphingosine_receptor_agonist: [3.74456803e-01 0.00000000e+00 7.55146813e-17 6.25543197e-01]
#
# [00:00] Optimised Blend OOF for src_inhibitor: 0.012078625259180374
# Optimised Weights for src_inhibitor: [0.119291   0.10109319 0.08964558 0.68997023]
#
# [00:00] Optimised Blend OOF for steroid: 0.002535731087530202
# Optimised Weights for steroid: [1.64798730e-16 0.00000000e+00 2.13586162e-01 7.86413838e-01]
#
# [00:00] Optimised Blend OOF for syk_inhibitor: 0.004868928249396607
# Optimised Weights for syk_inhibitor: [5.02605878e-02 1.24141149e-17 3.20735153e-01 6.29004259e-01]
#
# [00:00] Optimised Blend OOF for tachykinin_antagonist: 0.01763125740859612
# Optimised Weights for tachykinin_antagonist: [1.42538629e-01 2.23210122e-17 1.65809199e-01 6.91652172e-01]
#
# [00:00] Optimised Blend OOF for tgf-beta_receptor_inhibitor: 0.00207155501273443
# Optimised Weights for tgf-beta_receptor_inhibitor: [0.        0.        0.4337955 0.5662045]
#
# [00:00] Optimised Blend OOF for thrombin_inhibitor: 0.006142918114412866
# Optimised Weights for thrombin_inhibitor: [1.30158471e-16 9.07329684e-17 8.43709051e-04 9.99156291e-01]
#
# [00:00] Optimised Blend OOF for thymidylate_synthase_inhibitor: 0.009663447737555635
# Optimised Weights for thymidylate_synthase_inhibitor: [8.13151629e-19 6.58229564e-01 9.50470009e-02 2.46723435e-01]
#
# [00:00] Optimised Blend OOF for tlr_agonist: 0.010139163928543788
# Optimised Weights for tlr_agonist: [2.77555756e-17 6.41254395e-01 3.58745605e-01 0.00000000e+00]
#
# [00:00] Optimised Blend OOF for tlr_antagonist: 0.0028407839661561433
# Optimised Weights for tlr_antagonist: [5.05238212e-17 4.51847185e-02 2.15824283e-17 9.54815282e-01]
#
# [00:00] Optimised Blend OOF for tnf_inhibitor: 0.01087617360411011
# Optimised Weights for tnf_inhibitor: [0.0269834  0.15750729 0.44098751 0.3745218 ]
#
# [00:00] Optimised Blend OOF for topoisomerase_inhibitor: 0.010921781545050174
# Optimised Weights for topoisomerase_inhibitor: [0.47387274 0.         0.25619675 0.26993051]
#
# [00:00] Optimised Blend OOF for transient_receptor_potential_channel_antagonist: 0.006312703993877657
# Optimised Weights for transient_receptor_potential_channel_antagonist: [0.23517819 0.         0.36084246 0.40397935]
#
# [00:00] Optimised Blend OOF for tropomyosin_receptor_kinase_inhibitor: 0.0024462532033681646
# Optimised Weights for tropomyosin_receptor_kinase_inhibitor: [0.00000000e+00 1.68634633e-16 1.00000000e+00 0.00000000e+00]
#
# [00:00] Optimised Blend OOF for trpv_agonist: 0.005485209065662861
# Optimised Weights for trpv_agonist: [0.49009509 0.         0.11883781 0.3910671 ]
#
# [00:00] Optimised Blend OOF for trpv_antagonist: 0.014797906015881244
# Optimised Weights for trpv_antagonist: [0.17902036 0.05472279 0.51521697 0.25103988]
#
# [00:00] Optimised Blend OOF for tubulin_inhibitor: 0.018221289881310537
# Optimised Weights for tubulin_inhibitor: [0.02521805 0.25163542 0.30325505 0.41989149]
#
# [00:00] Optimised Blend OOF for tyrosine_kinase_inhibitor: 0.01662498003660345
# Optimised Weights for tyrosine_kinase_inhibitor: [1.68100732e-01 3.08319993e-18 4.33947525e-01 3.97951743e-01]
#
# [00:00] Optimised Blend OOF for ubiquitin_specific_protease_inhibitor: 0.002577795397491189
# Optimised Weights for ubiquitin_specific_protease_inhibitor: [1.22731686e-16 7.12771998e-17 5.09556864e-01 4.90443136e-01]
#
# [00:00] Optimised Blend OOF for vegfr_inhibitor: 0.020230214184789756
# Optimised Weights for vegfr_inhibitor: [0.34353114 0.04194319 0.16948357 0.44504209]
#
# [00:00] Optimised Blend OOF for vitamin_b: 0.008823503997923154
# Optimised Weights for vitamin_b: [0.21208643 0.21887388 0.49660397 0.07243571]
#
# [00:00] Optimised Blend OOF for vitamin_d_receptor_agonist: 0.00424639715752181
# Optimised Weights for vitamin_d_receptor_agonist: [0.00000000e+00 9.90030932e-01 9.96906784e-03 7.47434737e-18]
#
# [00:00] Optimised Blend OOF for wnt_inhibitor: 0.009634765577282378
# Optimised Weights for wnt_inhibitor: [0.32844548 0.         0.40129447 0.27026005]
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_2stageNN_ns_oldcv.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/2stageNN_with_ns_oldcv.py: 0.015606
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_script_simpleNN_oldcv.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/script_simpleNN_oldcv.py: 0.015846
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_deepinsight_efficientnet_lightning_v7_b3_0.01850.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/deepinsight_efficientnet_lightning_v7_b3_infer.py: 0.016016
#
# Loading OOF from ../../Github/kaggle_moa_team/oof/oof_deepinsight_ResNeSt_v2_resnest50_0.01854.npy ......
# OOF Validation Loss of ../../Github/kaggle_moa_team/scripts/deepinsight_resnest_lightning_v2_infer.py: 0.015756
#
# Blend Target-Wise OOF Validation Loss: 0.015044

# %%
total_elapsed = time.time() - total_start
print(f"Total time spent: {total_elapsed/60:.2f} minutes.")
# Out:
# Total time spent: 0.69 minutes.

# %%
# [V6 - without TabNet, 2heads]
# Total time spent: 0.68 minutes.
# Blend Target-Wise OOF Validation Loss: 0.015044

# %%
# [V6 - without TabNet, 2heads]
# [Optuna]
# Number of finished trials: 3000
# Best trial:
#   Value: 0.015171999561900233
#   Params: 
#     w0: 0.323528084383917
#     w1: 0.08786476491118465
#     w2: 0.21849845883367852
#     w3: 0.3704230222796271

# [Scipy SLSQP]
# [00:22] Optimised Blend OOF: 0.015172004593585666
# Optimised Weights: [0.32020133 0.09043987 0.22122948 0.36812932]

# %%
# [V6 - without TabNet]
# [Optuna]
# Number of finished trials: 3000
# Best trial:
#   Value: 0.015172424601530761
#   Params: 
#     w0: 0.3138176484100186
#     w1: 0.07850519440561339
#     w2: 0.0007183363099561991
#     w3: 0.23849563017967007
#     w4: 0.3694870328388392

# [Scipy SLSQP]
# [00:21] Optimised Blend OOF: 0.015172004898867827
# Optimised Weights: [0.32045559 0.09026525 0.         0.22069638 0.36858278]

# %%
# [V6]
# [Optuna]
# Number of finished trials: 5000
# Best trial:
#   Value: 0.015173437622007157
#   Params: 
#     w0: 0.30923325055652684
#     w1: 0.09831493504786226
#     w2: 0.018966959973949222
#     w3: 0.19863369862866234
#     w4: 0.0013224625996093413
#     w5: 0.3728865483320761

# [Scipy SLSQP]
# [00:36] Optimised Blend OOF: 0.015172005464591968
# Optimised Weights: [3.20472642e-01 9.01191588e-02 1.78893358e-18 2.20448482e-01
#  3.27971157e-18 3.68959717e-01]

# %%
# [V5]
# Number of finished trials: 3000
# Best trial:
#   Value: 0.015344701181290615
#   Params: 
#     w0: 0.5141433844379889
#     w1: 0.11747776562133813
#     w2: 0.3668324643717302

# [00:14] Optimised Blend OOF: 0.015344695215068541
# Optimised Weights: [0.51922623 0.11292509 0.36784869]

# %%
# [V4]
# [Optuna]
# Number of finished trials: 3000
# Best trial:
#   Value: 0.015331901615194453
#   Params: 
#     w0: 0.4505928450756189
#     w1: 0.13010257032841785
#     w2: 0.06308933354044946
#     w3: 0.35639153615958885
#
# [Scipy]
# [00:23] Optimised Blend OOF: 0.015331777381591449
# Optimised Weights: [0.44090106 0.14508641 0.05945655 0.35455598]

# %%
# [V3]
# improving-mark-s-2-heads-model-infer
# Number of finished trials: 3000
# Best trial:
#   Value: 0.01515466145873492
#   Params: 
#     w0: 0.0002980690037490555
#     w1: 0.29771381784976886
#     w2: 0.1569191862042946
#     w3: 0.18156875605872544
#     w4: 0.36371774630338105

# %%
# [V3]
# fork-of-2heads-looper-super-puper-markpeng-infer
# Number of finished trials: 3000
# Best trial:
#   Value: 0.015170138066049686
#   Params: 
#     w0: 0.00019903389488299251
#     w1: 0.3853752127955825
#     w2: 0.015968332256452233
#     w3: 0.22945916769823432
#     w4: 0.3711290150522236

# %%
if search_mode and method == "scipy_per_target":
    # OOF scores per target
    target_oof_losses = []
    for i, target in enumerate(train_classes):
        print(target)
        # print(y_true[:, i])

        oof_loss = mean_logloss(blend_targets_oof[:, i], y_true[:, i])
        target_oof_losses.append(oof_loss)
        print(f"Blend OOF Validation Loss of {target}: {oof_loss:.6f}\n")

    target_loss_df = pd.DataFrame(
        data={
            "target": train_classes,
            "oof_logloss": target_oof_losses
        },
        columns=["target", "oof_logloss"
                 ]).sort_values(by="oof_logloss",
                                ascending=False).reset_index(drop=True)
    print(target_loss_df)
# Out:
# 5-alpha_reductase_inhibitor
# Blend OOF Validation Loss of 5-alpha_reductase_inhibitor: 0.005349
#
# 11-beta-hsd1_inhibitor
# Blend OOF Validation Loss of 11-beta-hsd1_inhibitor: 0.006129
#
# acat_inhibitor
# Blend OOF Validation Loss of acat_inhibitor: 0.007892
#
# acetylcholine_receptor_agonist
# Blend OOF Validation Loss of acetylcholine_receptor_agonist: 0.046302
#
# acetylcholine_receptor_antagonist
# Blend OOF Validation Loss of acetylcholine_receptor_antagonist: 0.067858
#
# acetylcholinesterase_inhibitor
# Blend OOF Validation Loss of acetylcholinesterase_inhibitor: 0.021333
#
# adenosine_receptor_agonist
# Blend OOF Validation Loss of adenosine_receptor_agonist: 0.015513
#
# adenosine_receptor_antagonist
# Blend OOF Validation Loss of adenosine_receptor_antagonist: 0.025136
#
# adenylyl_cyclase_activator
# Blend OOF Validation Loss of adenylyl_cyclase_activator: 0.001430
#
# adrenergic_receptor_agonist
# Blend OOF Validation Loss of adrenergic_receptor_agonist: 0.051798
#
# adrenergic_receptor_antagonist
# Blend OOF Validation Loss of adrenergic_receptor_antagonist: 0.078698
#
# akt_inhibitor
# Blend OOF Validation Loss of akt_inhibitor: 0.009399
#
# aldehyde_dehydrogenase_inhibitor
# Blend OOF Validation Loss of aldehyde_dehydrogenase_inhibitor: 0.001195
#
# alk_inhibitor
# Blend OOF Validation Loss of alk_inhibitor: 0.008126
#
# ampk_activator
# Blend OOF Validation Loss of ampk_activator: 0.004561
#
# analgesic
# Blend OOF Validation Loss of analgesic: 0.004442
#
# androgen_receptor_agonist
# Blend OOF Validation Loss of androgen_receptor_agonist: 0.014503
#
# androgen_receptor_antagonist
# Blend OOF Validation Loss of androgen_receptor_antagonist: 0.024673
#
# anesthetic_-_local
# Blend OOF Validation Loss of anesthetic_-_local: 0.022892
#
# angiogenesis_inhibitor
# Blend OOF Validation Loss of angiogenesis_inhibitor: 0.011044
#
# angiotensin_receptor_antagonist
# Blend OOF Validation Loss of angiotensin_receptor_antagonist: 0.011768
#
# anti-inflammatory
# Blend OOF Validation Loss of anti-inflammatory: 0.019655
#
# antiarrhythmic
# Blend OOF Validation Loss of antiarrhythmic: 0.002494
#
# antibiotic
# Blend OOF Validation Loss of antibiotic: 0.011437
#
# anticonvulsant
# Blend OOF Validation Loss of anticonvulsant: 0.004521
#
# antifungal
# Blend OOF Validation Loss of antifungal: 0.004399
#
# antihistamine
# Blend OOF Validation Loss of antihistamine: 0.004371
#
# antimalarial
# Blend OOF Validation Loss of antimalarial: 0.005773
#
# antioxidant
# Blend OOF Validation Loss of antioxidant: 0.021082
#
# antiprotozoal
# Blend OOF Validation Loss of antiprotozoal: 0.011406
#
# antiviral
# Blend OOF Validation Loss of antiviral: 0.008056
#
# apoptosis_stimulant
# Blend OOF Validation Loss of apoptosis_stimulant: 0.013408
#
# aromatase_inhibitor
# Blend OOF Validation Loss of aromatase_inhibitor: 0.014546
#
# atm_kinase_inhibitor
# Blend OOF Validation Loss of atm_kinase_inhibitor: 0.001768
#
# atp-sensitive_potassium_channel_antagonist
# Blend OOF Validation Loss of atp-sensitive_potassium_channel_antagonist: 0.000850
#
# atp_synthase_inhibitor
# Blend OOF Validation Loss of atp_synthase_inhibitor: 0.001051
#
# atpase_inhibitor
# Blend OOF Validation Loss of atpase_inhibitor: 0.019703
#
# atr_kinase_inhibitor
# Blend OOF Validation Loss of atr_kinase_inhibitor: 0.002670
#
# aurora_kinase_inhibitor
# Blend OOF Validation Loss of aurora_kinase_inhibitor: 0.007809
#
# autotaxin_inhibitor
# Blend OOF Validation Loss of autotaxin_inhibitor: 0.002192
#
# bacterial_30s_ribosomal_subunit_inhibitor
# Blend OOF Validation Loss of bacterial_30s_ribosomal_subunit_inhibitor: 0.017627
#
# bacterial_50s_ribosomal_subunit_inhibitor
# Blend OOF Validation Loss of bacterial_50s_ribosomal_subunit_inhibitor: 0.021280
#
# bacterial_antifolate
# Blend OOF Validation Loss of bacterial_antifolate: 0.011215
#
# bacterial_cell_wall_synthesis_inhibitor
# Blend OOF Validation Loss of bacterial_cell_wall_synthesis_inhibitor: 0.047185
#
# bacterial_dna_gyrase_inhibitor
# Blend OOF Validation Loss of bacterial_dna_gyrase_inhibitor: 0.024431
#
# bacterial_dna_inhibitor
# Blend OOF Validation Loss of bacterial_dna_inhibitor: 0.029956
#
# bacterial_membrane_integrity_inhibitor
# Blend OOF Validation Loss of bacterial_membrane_integrity_inhibitor: 0.001396
#
# bcl_inhibitor
# Blend OOF Validation Loss of bcl_inhibitor: 0.007436
#
# bcr-abl_inhibitor
# Blend OOF Validation Loss of bcr-abl_inhibitor: 0.006427
#
# benzodiazepine_receptor_agonist
# Blend OOF Validation Loss of benzodiazepine_receptor_agonist: 0.019178
#
# beta_amyloid_inhibitor
# Blend OOF Validation Loss of beta_amyloid_inhibitor: 0.008513
#
# bromodomain_inhibitor
# Blend OOF Validation Loss of bromodomain_inhibitor: 0.012087
#
# btk_inhibitor
# Blend OOF Validation Loss of btk_inhibitor: 0.006304
#
# calcineurin_inhibitor
# Blend OOF Validation Loss of calcineurin_inhibitor: 0.002543
#
# calcium_channel_blocker
# Blend OOF Validation Loss of calcium_channel_blocker: 0.062166
#
# cannabinoid_receptor_agonist
# Blend OOF Validation Loss of cannabinoid_receptor_agonist: 0.012524
#
# cannabinoid_receptor_antagonist
# Blend OOF Validation Loss of cannabinoid_receptor_antagonist: 0.016013
#
# carbonic_anhydrase_inhibitor
# Blend OOF Validation Loss of carbonic_anhydrase_inhibitor: 0.011728
#
# casein_kinase_inhibitor
# Blend OOF Validation Loss of casein_kinase_inhibitor: 0.010107
#
# caspase_activator
# Blend OOF Validation Loss of caspase_activator: 0.006404
#
# catechol_o_methyltransferase_inhibitor
# Blend OOF Validation Loss of catechol_o_methyltransferase_inhibitor: 0.004789
#
# cc_chemokine_receptor_antagonist
# Blend OOF Validation Loss of cc_chemokine_receptor_antagonist: 0.027879
#
# cck_receptor_antagonist
# Blend OOF Validation Loss of cck_receptor_antagonist: 0.006584
#
# cdk_inhibitor
# Blend OOF Validation Loss of cdk_inhibitor: 0.015079
#
# chelating_agent
# Blend OOF Validation Loss of chelating_agent: 0.016349
#
# chk_inhibitor
# Blend OOF Validation Loss of chk_inhibitor: 0.001693
#
# chloride_channel_blocker
# Blend OOF Validation Loss of chloride_channel_blocker: 0.012799
#
# cholesterol_inhibitor
# Blend OOF Validation Loss of cholesterol_inhibitor: 0.015037
#
# cholinergic_receptor_antagonist
# Blend OOF Validation Loss of cholinergic_receptor_antagonist: 0.015968
#
# coagulation_factor_inhibitor
# Blend OOF Validation Loss of coagulation_factor_inhibitor: 0.002558
#
# corticosteroid_agonist
# Blend OOF Validation Loss of corticosteroid_agonist: 0.008128
#
# cyclooxygenase_inhibitor
# Blend OOF Validation Loss of cyclooxygenase_inhibitor: 0.088091
#
# cytochrome_p450_inhibitor
# Blend OOF Validation Loss of cytochrome_p450_inhibitor: 0.027622
#
# dihydrofolate_reductase_inhibitor
# Blend OOF Validation Loss of dihydrofolate_reductase_inhibitor: 0.007697
#
# dipeptidyl_peptidase_inhibitor
# Blend OOF Validation Loss of dipeptidyl_peptidase_inhibitor: 0.008226
#
# diuretic
# Blend OOF Validation Loss of diuretic: 0.002544
#
# dna_alkylating_agent
# Blend OOF Validation Loss of dna_alkylating_agent: 0.014481
#
# dna_inhibitor
# Blend OOF Validation Loss of dna_inhibitor: 0.076250
#
# dopamine_receptor_agonist
# Blend OOF Validation Loss of dopamine_receptor_agonist: 0.031282
#
# dopamine_receptor_antagonist
# Blend OOF Validation Loss of dopamine_receptor_antagonist: 0.084252
#
# egfr_inhibitor
# Blend OOF Validation Loss of egfr_inhibitor: 0.012911
#
# elastase_inhibitor
# Blend OOF Validation Loss of elastase_inhibitor: 0.002469
#
# erbb2_inhibitor
# Blend OOF Validation Loss of erbb2_inhibitor: 0.000858
#
# estrogen_receptor_agonist
# Blend OOF Validation Loss of estrogen_receptor_agonist: 0.038783
#
# estrogen_receptor_antagonist
# Blend OOF Validation Loss of estrogen_receptor_antagonist: 0.013508
#
# faah_inhibitor
# Blend OOF Validation Loss of faah_inhibitor: 0.009896
#
# farnesyltransferase_inhibitor
# Blend OOF Validation Loss of farnesyltransferase_inhibitor: 0.002276
#
# fatty_acid_receptor_agonist
# Blend OOF Validation Loss of fatty_acid_receptor_agonist: 0.008219
#
# fgfr_inhibitor
# Blend OOF Validation Loss of fgfr_inhibitor: 0.008161
#
# flt3_inhibitor
# Blend OOF Validation Loss of flt3_inhibitor: 0.014245
#
# focal_adhesion_kinase_inhibitor
# Blend OOF Validation Loss of focal_adhesion_kinase_inhibitor: 0.001095
#
# free_radical_scavenger
# Blend OOF Validation Loss of free_radical_scavenger: 0.006335
#
# fungal_squalene_epoxidase_inhibitor
# Blend OOF Validation Loss of fungal_squalene_epoxidase_inhibitor: 0.006125
#
# gaba_receptor_agonist
# Blend OOF Validation Loss of gaba_receptor_agonist: 0.027962
#
# gaba_receptor_antagonist
# Blend OOF Validation Loss of gaba_receptor_antagonist: 0.041255
#
# gamma_secretase_inhibitor
# Blend OOF Validation Loss of gamma_secretase_inhibitor: 0.008586
#
# glucocorticoid_receptor_agonist
# Blend OOF Validation Loss of glucocorticoid_receptor_agonist: 0.013678
#
# glutamate_inhibitor
# Blend OOF Validation Loss of glutamate_inhibitor: 0.004292
#
# glutamate_receptor_agonist
# Blend OOF Validation Loss of glutamate_receptor_agonist: 0.021533
#
# glutamate_receptor_antagonist
# Blend OOF Validation Loss of glutamate_receptor_antagonist: 0.080409
#
# gonadotropin_receptor_agonist
# Blend OOF Validation Loss of gonadotropin_receptor_agonist: 0.006238
#
# gsk_inhibitor
# Blend OOF Validation Loss of gsk_inhibitor: 0.008838
#
# hcv_inhibitor
# Blend OOF Validation Loss of hcv_inhibitor: 0.020602
#
# hdac_inhibitor
# Blend OOF Validation Loss of hdac_inhibitor: 0.009543
#
# histamine_receptor_agonist
# Blend OOF Validation Loss of histamine_receptor_agonist: 0.017740
#
# histamine_receptor_antagonist
# Blend OOF Validation Loss of histamine_receptor_antagonist: 0.056867
#
# histone_lysine_demethylase_inhibitor
# Blend OOF Validation Loss of histone_lysine_demethylase_inhibitor: 0.004186
#
# histone_lysine_methyltransferase_inhibitor
# Blend OOF Validation Loss of histone_lysine_methyltransferase_inhibitor: 0.009231
#
# hiv_inhibitor
# Blend OOF Validation Loss of hiv_inhibitor: 0.019892
#
# hmgcr_inhibitor
# Blend OOF Validation Loss of hmgcr_inhibitor: 0.007926
#
# hsp_inhibitor
# Blend OOF Validation Loss of hsp_inhibitor: 0.006860
#
# igf-1_inhibitor
# Blend OOF Validation Loss of igf-1_inhibitor: 0.007320
#
# ikk_inhibitor
# Blend OOF Validation Loss of ikk_inhibitor: 0.005934
#
# imidazoline_receptor_agonist
# Blend OOF Validation Loss of imidazoline_receptor_agonist: 0.010308
#
# immunosuppressant
# Blend OOF Validation Loss of immunosuppressant: 0.016879
#
# insulin_secretagogue
# Blend OOF Validation Loss of insulin_secretagogue: 0.010003
#
# insulin_sensitizer
# Blend OOF Validation Loss of insulin_sensitizer: 0.010540
#
# integrin_inhibitor
# Blend OOF Validation Loss of integrin_inhibitor: 0.012417
#
# jak_inhibitor
# Blend OOF Validation Loss of jak_inhibitor: 0.008909
#
# kit_inhibitor
# Blend OOF Validation Loss of kit_inhibitor: 0.012787
#
# laxative
# Blend OOF Validation Loss of laxative: 0.002613
#
# leukotriene_inhibitor
# Blend OOF Validation Loss of leukotriene_inhibitor: 0.002590
#
# leukotriene_receptor_antagonist
# Blend OOF Validation Loss of leukotriene_receptor_antagonist: 0.017751
#
# lipase_inhibitor
# Blend OOF Validation Loss of lipase_inhibitor: 0.004614
#
# lipoxygenase_inhibitor
# Blend OOF Validation Loss of lipoxygenase_inhibitor: 0.016493
#
# lxr_agonist
# Blend OOF Validation Loss of lxr_agonist: 0.001514
#
# mdm_inhibitor
# Blend OOF Validation Loss of mdm_inhibitor: 0.003021
#
# mek_inhibitor
# Blend OOF Validation Loss of mek_inhibitor: 0.005756
#
# membrane_integrity_inhibitor
# Blend OOF Validation Loss of membrane_integrity_inhibitor: 0.020388
#
# mineralocorticoid_receptor_antagonist
# Blend OOF Validation Loss of mineralocorticoid_receptor_antagonist: 0.008186
#
# monoacylglycerol_lipase_inhibitor
# Blend OOF Validation Loss of monoacylglycerol_lipase_inhibitor: 0.004519
#
# monoamine_oxidase_inhibitor
# Blend OOF Validation Loss of monoamine_oxidase_inhibitor: 0.024181
#
# monopolar_spindle_1_kinase_inhibitor
# Blend OOF Validation Loss of monopolar_spindle_1_kinase_inhibitor: 0.004773
#
# mtor_inhibitor
# Blend OOF Validation Loss of mtor_inhibitor: 0.013148
#
# mucolytic_agent
# Blend OOF Validation Loss of mucolytic_agent: 0.014870
#
# neuropeptide_receptor_antagonist
# Blend OOF Validation Loss of neuropeptide_receptor_antagonist: 0.011162
#
# nfkb_inhibitor
# Blend OOF Validation Loss of nfkb_inhibitor: 0.029202
#
# nicotinic_receptor_agonist
# Blend OOF Validation Loss of nicotinic_receptor_agonist: 0.002566
#
# nitric_oxide_donor
# Blend OOF Validation Loss of nitric_oxide_donor: 0.008482
#
# nitric_oxide_production_inhibitor
# Blend OOF Validation Loss of nitric_oxide_production_inhibitor: 0.003419
#
# nitric_oxide_synthase_inhibitor
# Blend OOF Validation Loss of nitric_oxide_synthase_inhibitor: 0.008818
#
# norepinephrine_reuptake_inhibitor
# Blend OOF Validation Loss of norepinephrine_reuptake_inhibitor: 0.002904
#
# nrf2_activator
# Blend OOF Validation Loss of nrf2_activator: 0.003814
#
# opioid_receptor_agonist
# Blend OOF Validation Loss of opioid_receptor_agonist: 0.018157
#
# opioid_receptor_antagonist
# Blend OOF Validation Loss of opioid_receptor_antagonist: 0.026088
#
# orexin_receptor_antagonist
# Blend OOF Validation Loss of orexin_receptor_antagonist: 0.011694
#
# p38_mapk_inhibitor
# Blend OOF Validation Loss of p38_mapk_inhibitor: 0.007495
#
# p-glycoprotein_inhibitor
# Blend OOF Validation Loss of p-glycoprotein_inhibitor: 0.006932
#
# parp_inhibitor
# Blend OOF Validation Loss of parp_inhibitor: 0.014882
#
# pdgfr_inhibitor
# Blend OOF Validation Loss of pdgfr_inhibitor: 0.013974
#
# pdk_inhibitor
# Blend OOF Validation Loss of pdk_inhibitor: 0.005642
#
# phosphodiesterase_inhibitor
# Blend OOF Validation Loss of phosphodiesterase_inhibitor: 0.059088
#
# phospholipase_inhibitor
# Blend OOF Validation Loss of phospholipase_inhibitor: 0.008288
#
# pi3k_inhibitor
# Blend OOF Validation Loss of pi3k_inhibitor: 0.021468
#
# pkc_inhibitor
# Blend OOF Validation Loss of pkc_inhibitor: 0.007834
#
# potassium_channel_activator
# Blend OOF Validation Loss of potassium_channel_activator: 0.016349
#
# potassium_channel_antagonist
# Blend OOF Validation Loss of potassium_channel_antagonist: 0.027003
#
# ppar_receptor_agonist
# Blend OOF Validation Loss of ppar_receptor_agonist: 0.021717
#
# ppar_receptor_antagonist
# Blend OOF Validation Loss of ppar_receptor_antagonist: 0.008729
#
# progesterone_receptor_agonist
# Blend OOF Validation Loss of progesterone_receptor_agonist: 0.026860
#
# progesterone_receptor_antagonist
# Blend OOF Validation Loss of progesterone_receptor_antagonist: 0.004622
#
# prostaglandin_inhibitor
# Blend OOF Validation Loss of prostaglandin_inhibitor: 0.011605
#
# prostanoid_receptor_antagonist
# Blend OOF Validation Loss of prostanoid_receptor_antagonist: 0.023668
#
# proteasome_inhibitor
# Blend OOF Validation Loss of proteasome_inhibitor: 0.001129
#
# protein_kinase_inhibitor
# Blend OOF Validation Loss of protein_kinase_inhibitor: 0.013985
#
# protein_phosphatase_inhibitor
# Blend OOF Validation Loss of protein_phosphatase_inhibitor: 0.002067
#
# protein_synthesis_inhibitor
# Blend OOF Validation Loss of protein_synthesis_inhibitor: 0.021379
#
# protein_tyrosine_kinase_inhibitor
# Blend OOF Validation Loss of protein_tyrosine_kinase_inhibitor: 0.006221
#
# radiopaque_medium
# Blend OOF Validation Loss of radiopaque_medium: 0.016787
#
# raf_inhibitor
# Blend OOF Validation Loss of raf_inhibitor: 0.004242
#
# ras_gtpase_inhibitor
# Blend OOF Validation Loss of ras_gtpase_inhibitor: 0.003538
#
# retinoid_receptor_agonist
# Blend OOF Validation Loss of retinoid_receptor_agonist: 0.007879
#
# retinoid_receptor_antagonist
# Blend OOF Validation Loss of retinoid_receptor_antagonist: 0.002505
#
# rho_associated_kinase_inhibitor
# Blend OOF Validation Loss of rho_associated_kinase_inhibitor: 0.007342
#
# ribonucleoside_reductase_inhibitor
# Blend OOF Validation Loss of ribonucleoside_reductase_inhibitor: 0.008643
#
# rna_polymerase_inhibitor
# Blend OOF Validation Loss of rna_polymerase_inhibitor: 0.007899
#
# serotonin_receptor_agonist
# Blend OOF Validation Loss of serotonin_receptor_agonist: 0.055973
#
# serotonin_receptor_antagonist
# Blend OOF Validation Loss of serotonin_receptor_antagonist: 0.083194
#
# serotonin_reuptake_inhibitor
# Blend OOF Validation Loss of serotonin_reuptake_inhibitor: 0.013270
#
# sigma_receptor_agonist
# Blend OOF Validation Loss of sigma_receptor_agonist: 0.011861
#
# sigma_receptor_antagonist
# Blend OOF Validation Loss of sigma_receptor_antagonist: 0.011557
#
# smoothened_receptor_antagonist
# Blend OOF Validation Loss of smoothened_receptor_antagonist: 0.008063
#
# sodium_channel_inhibitor
# Blend OOF Validation Loss of sodium_channel_inhibitor: 0.062615
#
# sphingosine_receptor_agonist
# Blend OOF Validation Loss of sphingosine_receptor_agonist: 0.008136
#
# src_inhibitor
# Blend OOF Validation Loss of src_inhibitor: 0.012079
#
# steroid
# Blend OOF Validation Loss of steroid: 0.002536
#
# syk_inhibitor
# Blend OOF Validation Loss of syk_inhibitor: 0.004869
#
# tachykinin_antagonist
# Blend OOF Validation Loss of tachykinin_antagonist: 0.017631
#
# tgf-beta_receptor_inhibitor
# Blend OOF Validation Loss of tgf-beta_receptor_inhibitor: 0.002072
#
# thrombin_inhibitor
# Blend OOF Validation Loss of thrombin_inhibitor: 0.006143
#
# thymidylate_synthase_inhibitor
# Blend OOF Validation Loss of thymidylate_synthase_inhibitor: 0.009663
#
# tlr_agonist
# Blend OOF Validation Loss of tlr_agonist: 0.010139
#
# tlr_antagonist
# Blend OOF Validation Loss of tlr_antagonist: 0.002841
#
# tnf_inhibitor
# Blend OOF Validation Loss of tnf_inhibitor: 0.010876
#
# topoisomerase_inhibitor
# Blend OOF Validation Loss of topoisomerase_inhibitor: 0.010922
#
# transient_receptor_potential_channel_antagonist
# Blend OOF Validation Loss of transient_receptor_potential_channel_antagonist: 0.006313
#
# tropomyosin_receptor_kinase_inhibitor
# Blend OOF Validation Loss of tropomyosin_receptor_kinase_inhibitor: 0.002446
#
# trpv_agonist
# Blend OOF Validation Loss of trpv_agonist: 0.005485
#
# trpv_antagonist
# Blend OOF Validation Loss of trpv_antagonist: 0.014798
#
# tubulin_inhibitor
# Blend OOF Validation Loss of tubulin_inhibitor: 0.018221
#
# tyrosine_kinase_inhibitor
# Blend OOF Validation Loss of tyrosine_kinase_inhibitor: 0.016625
#
# ubiquitin_specific_protease_inhibitor
# Blend OOF Validation Loss of ubiquitin_specific_protease_inhibitor: 0.002578
#
# vegfr_inhibitor
# Blend OOF Validation Loss of vegfr_inhibitor: 0.020230
#
# vitamin_b
# Blend OOF Validation Loss of vitamin_b: 0.008824
#
# vitamin_d_receptor_agonist
# Blend OOF Validation Loss of vitamin_d_receptor_agonist: 0.004246
#
# wnt_inhibitor
# Blend OOF Validation Loss of wnt_inhibitor: 0.009635
#
#                                          target  oof_logloss
# 0                      cyclooxygenase_inhibitor     0.088091
# 1                  dopamine_receptor_antagonist     0.084252
# 2                 serotonin_receptor_antagonist     0.083194
# 3                 glutamate_receptor_antagonist     0.080409
# 4                adrenergic_receptor_antagonist     0.078698
# ..                                          ...          ...
# 201                        proteasome_inhibitor     0.001129
# 202             focal_adhesion_kinase_inhibitor     0.001095
# 203                      atp_synthase_inhibitor     0.001051
# 204                             erbb2_inhibitor     0.000858
# 205  atp-sensitive_potassium_channel_antagonist     0.000850
#
# [206 rows x 2 columns]

# %%
if run_submit_script:
    print(submission.shape)
    print(submission)
    submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ## EOF

# %%
if kernel_mode:
    # !rm ./*.py
    # !ls -la
